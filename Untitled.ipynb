# %%
# !jupyter nbconvert "1. Robot Moving and Sensing.ipynb"
# !jupyter nbconvert "3. Landmark Detection and Tracking.ipynb"
# Out:
# [NbConvertApp] Converting notebook 1. Robot Moving and Sensing.ipynb to html
# [NbConvertApp] Writing 327728 bytes to 1. Robot Moving and Sensing.html
# [NbConvertApp] Converting notebook 3. Landmark Detection and Tracking.ipynb to html
# [NbConvertApp] Writing 421507 bytes to 3. Landmark Detection and Tracking.html

# %%
# !!apt-get -y update && apt-get install -y zip
# !zip project3.zip -r . -i@filelist.txt
# Out:
#   adding: filelist.txt (stored 0%)
#   adding: images/ (stored 0%)
#   adding: images/solution.png (deflated 11%)
#   adding: images/omega_xi.png (deflated 27%)
#   adding: images/omega_xi_constraints.png (deflated 13%)
#   adding: images/motion_constraint.png (deflated 30%)
#   adding: images/robot_world.png (deflated 15%)
#   adding: images/initial_constraints.png (deflated 47%)
#   adding: images/constraints2D.png (deflated 56%)
#   adding: robot_class.py (deflated 66%)
#   adding: 1. Robot Moving and Sensing.ipynb (deflated 53%)
#   adding: __pycache__/ (stored 0%)
#   adding: __pycache__/robot_class.cpython-37.pyc (deflated 48%)
#   adding: __pycache__/helpers.cpython-37.pyc (deflated 40%)
#   adding: .ipynb_checkpoints/ (stored 0%)
#   adding: .ipynb_checkpoints/3. Landmark Detection and Tracking-checkpoint.ipynb (deflated 56%)
#   adding: .ipynb_checkpoints/1. Robot Moving and Sensing-checkpoint.ipynb (deflated 53%)
#   adding: .ipynb_checkpoints/Untitled-checkpoint.ipynb (deflated 22%)
#   adding: .ipynb_checkpoints/2. Omega and Xi, Constraints-checkpoint.ipynb (deflated 61%)
#   adding: 1. Robot Moving and Sensing.html (deflated 80%)
#   adding: Untitled.ipynb (deflated 22%)
#   adding: 3. Landmark Detection and Tracking.html (deflated 78%)
#   adding: 2. Omega and Xi, Constraints.ipynb (deflated 61%)
#   adding: requirements.txt (deflated 17%)
#   adding: helpers.py (deflated 61%)
#   adding: LICENSE (deflated 41%)
#   adding: 3. Landmark Detection and Tracking.ipynb (deflated 56%)
#   adding: README.md (deflated 64%)
#   adding: .git/ (stored 0%)
#   adding: .git/packed-refs (deflated 9%)
#   adding: .git/hooks/ (stored 0%)
#   adding: .git/hooks/prepare-commit-msg.sample (deflated 46%)
#   adding: .git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: .git/hooks/update.sample (deflated 68%)
#   adding: .git/hooks/commit-msg.sample (deflated 44%)
#   adding: .git/hooks/pre-rebase.sample (deflated 59%)
#   adding: .git/hooks/post-update.sample (deflated 27%)
#   adding: .git/hooks/pre-push.sample (deflated 50%)
#   adding: .git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: .git/hooks/pre-commit.sample (deflated 43%)
#   adding: .git/logs/ (stored 0%)
#   adding: .git/logs/HEAD (deflated 26%)
#   adding: .git/logs/refs/ (stored 0%)
#   adding: .git/logs/refs/remotes/ (stored 0%)
#   adding: .git/logs/refs/remotes/origin/ (stored 0%)
#   adding: .git/logs/refs/remotes/origin/HEAD (deflated 26%)
#   adding: .git/logs/refs/heads/ (stored 0%)
#   adding: .git/logs/refs/heads/master (deflated 26%)
#   adding: .git/branches/ (stored 0%)
#   adding: .git/HEAD (stored 0%)
#   adding: .git/objects/ (stored 0%)
#   adding: .git/objects/4c/ (stored 0%)
#   adding: .git/objects/4c/1d1ccb4e227a2ab59794e56c8d22939ca8d807 (stored 0%)
#   adding: .git/objects/9d/ (stored 0%)
#   adding: .git/objects/9d/795b15a6bc6f9a8233eb57d6bc7aea005517c9 (stored 0%)
#   adding: .git/objects/fc/ (stored 0%)
#   adding: .git/objects/fc/4ea7d27bef93d2ba6490bcc5f1f5f7433b0970 (stored 0%)
#   adding: .git/objects/cf/ (stored 0%)
#   adding: .git/objects/cf/e552650b10ed3cf7cb6f4bfcad5100645bf8e2 (stored 0%)
#   adding: .git/objects/33/ (stored 0%)
#   adding: .git/objects/33/de6e38b309d351fa5aef0e657944d298d7d4c4 (stored 0%)
#   adding: .git/objects/33/a133e612d618fd831280004678937290cb030d (stored 0%)
#   adding: .git/objects/6f/ (stored 0%)
#   adding: .git/objects/6f/a5c2ac62feea02991fdfe972bbe91a7de48449 (stored 0%)
#   adding: .git/objects/34/ (stored 0%)
#   adding: .git/objects/34/c7807227110477acb6b45a8bc0e6c85b96c28d (stored 0%)
#   adding: .git/objects/bf/ (stored 0%)
#   adding: .git/objects/bf/09fb5b2a5d5c57d6175109e480a5bf541b83d3 (stored 0%)
#   adding: .git/objects/d9/ (stored 0%)
#   adding: .git/objects/d9/d849af14c80c3a82429a5a847998f7c0b7cf28 (stored 0%)
#   adding: .git/objects/5f/ (stored 0%)
#   adding: .git/objects/5f/f892479fdffd8ab948bbe689ce222b747f2ca0 (stored 0%)
#   adding: .git/objects/c3/ (stored 0%)
#   adding: .git/objects/c3/4d425c278e1398aa351a75f189f19c0cf401e0 (stored 0%)
#   adding: .git/objects/af/ (stored 0%)
#   adding: .git/objects/af/b5bf473b91354186f7d0abde80fc906a36a9c0 (stored 0%)
#   adding: .git/objects/af/8becf0838723f848713c4b261401aa43b4712e (stored 0%)
#   adding: .git/objects/d2/ (stored 0%)
#   adding: .git/objects/d2/c7817e5e8639a29b87417cc5867d988120739f (stored 0%)
#   adding: .git/objects/d2/79d8476116024ff18c5e629fce71b9e3c85537 (stored 0%)
#   adding: .git/objects/b5/ (stored 0%)
#   adding: .git/objects/b5/6e4d5404fcab48972d0d6c176db00da3bbaf5d (stored 0%)
#   adding: .git/objects/7f/ (stored 0%)
#   adding: .git/objects/7f/e65dd8a6de3448ba5cfe2d32d3faf52180abf6 (stored 0%)
#   adding: .git/objects/7f/6c3059b25154f1d6708df1e2c16f2a945550f1 (stored 0%)
#   adding: .git/objects/45/ (stored 0%)
#   adding: .git/objects/45/dd32be6771d8bdf75fb7d783c6dd43648d91ca (stored 0%)
#   adding: .git/objects/e5/ (stored 0%)
#   adding: .git/objects/e5/445ad5dc410d64cb1342e62acb9dcd5288eec1 (stored 0%)
#   adding: .git/objects/4a/ (stored 0%)
#   adding: .git/objects/4a/6abb2fce8ce30f8cf482fe659c9e86cf7689b6 (stored 0%)
#   adding: .git/objects/da/ (stored 0%)
#   adding: .git/objects/da/479415ea5b57e047fd85d759c1a917876bbd97 (stored 0%)
#   adding: .git/objects/da/87b219e0798e2b8785066dbeccf4e215c21e08 (stored 0%)
#   adding: .git/objects/d1/ (stored 0%)
#   adding: .git/objects/d1/e034beaf6c083bd81b6f589fa3bfa8587acf1f (deflated 0%)
#   adding: .git/objects/d4/ (stored 0%)
#   adding: .git/objects/d4/38f35cbbf6818cec0a8e48b83f0102718ed4c3 (stored 0%)
#   adding: .git/objects/39/ (stored 0%)
#   adding: .git/objects/39/5bc8267945ea1ddb6d40ab69178c0e83cf984b (stored 0%)
#   adding: .git/objects/97/ (stored 0%)
#   adding: .git/objects/97/438f0a0c3e2f93219503fddb7b4900c0be876e (stored 0%)
#   adding: .git/objects/pack/ (stored 0%)
#   adding: .git/objects/ab/ (stored 0%)
#   adding: .git/objects/ab/cc2d8fc7ef30689313aa1bc84cd93648cb772f (deflated 0%)
#   adding: .git/objects/ac/ (stored 0%)
#   adding: .git/objects/ac/5e0bdd944ee96e4ec7617d3508cab2dc4a9f82 (stored 0%)
#   adding: .git/objects/ac/32fd1800c7e3ea3582d549797e18116f7110f5 (stored 0%)
#   adding: .git/objects/b4/ (stored 0%)
#   adding: .git/objects/b4/7b4c1df02a7797be7bcb9a1a1366d5f99c7c92 (deflated 0%)
#   adding: .git/objects/b4/aee4e45cc89c24dd49d181ba5ab2f84133ad55 (stored 0%)
#   adding: .git/objects/d7/ (stored 0%)
#   adding: .git/objects/d7/fc27c191ecbab9a45f3a02ef62edf3c691e55d (stored 0%)
#   adding: .git/objects/fe/ (stored 0%)
#   adding: .git/objects/fe/17179644faca2faefb8b0a8753f0e77edf3354 (deflated 0%)
#   adding: .git/objects/fe/af719d3ba39069d4dabaace8451b7512b2f23f (stored 0%)
#   adding: .git/objects/18/ (stored 0%)
#   adding: .git/objects/18/9b0346323b6da68be27dfc1f3ffb98528863ba (stored 0%)
#   adding: .git/objects/95/ (stored 0%)
#   adding: .git/objects/95/4f698152917d0c2204df1fb284467e3cdffcd1 (stored 0%)
#   adding: .git/objects/1d/ (stored 0%)
#   adding: .git/objects/1d/ee5af2c91959c82eb06c8343ee3c42d8cfa571 (stored 0%)
#   adding: .git/objects/28/ (stored 0%)
#   adding: .git/objects/28/4743c5c3341ca9431ac110d4e6f5b96ba94f23 (stored 0%)
#   adding: .git/objects/0a/ (stored 0%)
#   adding: .git/objects/0a/77fc82b7d154fe22f4ed220c20829c6a3ee085 (stored 0%)
#   adding: .git/objects/29/ (stored 0%)
#   adding: .git/objects/29/15b3cf49ee08c5b551da1ca572d557b1b6afe4 (stored 0%)
#   adding: .git/objects/4b/ (stored 0%)
#   adding: .git/objects/4b/ab0b24b112c15bb979685ebe04e7cfafb416ae (stored 0%)
#   adding: .git/objects/62/ (stored 0%)
#   adding: .git/objects/62/8b04821fab8514cfe254f63cac3dbcf8cede60 (stored 0%)
#   adding: .git/objects/62/ec23c54bc4e6ff0806d5a42c46100365959b24 (stored 0%)
#   adding: .git/objects/60/ (stored 0%)
#   adding: .git/objects/60/47643e4e3f71c438b8e4a9292aafff83d47c8a (stored 0%)
#   adding: .git/objects/60/50ba1872ab43c6ea4e4c8645facc1637e0f131 (stored 0%)
#   adding: .git/objects/31/ (stored 0%)
#   adding: .git/objects/31/b2d6cf5ab2a24fef2addeaa814421b2ec8d891 (stored 0%)
#   adding: .git/objects/c8/ (stored 0%)
#   adding: .git/objects/c8/510e284819124e68dbc5af0f20b91263312fd2 (stored 0%)
#   adding: .git/objects/6b/ (stored 0%)
#   adding: .git/objects/6b/28256c78b8a399ff1bb085602eeb1e6baf6104 (stored 0%)
#   adding: .git/objects/3e/ (stored 0%)
#   adding: .git/objects/3e/7868cd5c5aef4e72af0baabd1729891cc2f1a5 (stored 0%)
#   adding: .git/objects/cb/ (stored 0%)
#   adding: .git/objects/cb/f0737ae4bd4fe06f185a7066d1dfe72a0d04e6 (stored 0%)
#   adding: .git/objects/cb/7add62248af5c9c296cfac1582d744712adca9 (stored 0%)
#   adding: .git/objects/61/ (stored 0%)
#   adding: .git/objects/61/3f32d0fd077b904d88a42d0ca21380d08081ed (stored 0%)
#   adding: .git/objects/17/ (stored 0%)
#   adding: .git/objects/17/d2bc4f5d4c8683232e2d8927ecb9f4ededf6bd (stored 0%)
#   adding: .git/objects/0c/ (stored 0%)
#   adding: .git/objects/0c/f41af86da0b5abc139ff9c02f23ec8d90d6acb (stored 0%)
#   adding: .git/objects/4f/ (stored 0%)
#   adding: .git/objects/4f/5fb80b86cbbd6521cd5ede438092e187133959 (deflated 0%)
#   adding: .git/objects/70/ (stored 0%)
#   adding: .git/objects/70/1181857aae6e8f0f481fe061335f00ebdfca4c (deflated 0%)
#   adding: .git/objects/d8/ (stored 0%)
#   adding: .git/objects/d8/4db6a5579db34541293ecedb59623f5ec8c780 (stored 0%)
#   adding: .git/objects/8a/ (stored 0%)
#   adding: .git/objects/8a/c89f3ca362b40203bd6a47a61387bd6f6b47a9 (stored 0%)
#   adding: .git/objects/74/ (stored 0%)
#   adding: .git/objects/74/e75add27d09c62780b26fb7650d89f08451b31 (stored 0%)
#   adding: .git/objects/a9/ (stored 0%)
#   adding: .git/objects/a9/271c35c79eb404e6dccfaa72d2c643bb9f423a (stored 0%)
#   adding: .git/objects/23/ (stored 0%)
#   adding: .git/objects/23/d85166815b5f33d39b71878c5a56def012a1d9 (stored 0%)
#   adding: .git/objects/69/ (stored 0%)
#   adding: .git/objects/69/4b6187bad6e340cb96e59e91c05fefd6b3776d (stored 0%)
#   adding: .git/objects/05/ (stored 0%)
#   adding: .git/objects/05/88a5ad0fecd262efe2f7c68b885457a42cc41c (stored 0%)
#   adding: .git/objects/05/bd9600d795a6c3994cdb3cc4520b116cef2aac (stored 0%)
#   adding: .git/objects/ee/ (stored 0%)
#   adding: .git/objects/ee/6ffb92f5074d17f346935b47613fb9917f1343 (stored 0%)
#   adding: .git/objects/info/ (stored 0%)
#   adding: .git/objects/be/ (stored 0%)
#   adding: .git/objects/be/2c0f40755a92bf8cee24cc24b653aced34eea1 (stored 0%)
#   adding: .git/objects/be/77371ab417aa2427249e911a2b84c7a5bfd171 (stored 0%)
#   adding: .git/objects/6e/ (stored 0%)
#   adding: .git/objects/6e/1bae1a358fc8c3b08905a9826d275b3b53ff7a (stored 0%)
#   adding: .git/objects/68/ (stored 0%)
#   adding: .git/objects/68/673ad41888fa0c91291e97861d2d199a2421e9 (stored 0%)
#   adding: .git/objects/b6/ (stored 0%)
#   adding: .git/objects/b6/cfece775140d56eec766dd0c46450b1ce3d7c8 (stored 0%)
#   adding: .git/objects/f4/ (stored 0%)
#   adding: .git/objects/f4/e818b4993398c37b8ac7c0d612d1b748a13f7b (stored 0%)
#   adding: .git/objects/99/ (stored 0%)
#   adding: .git/objects/99/0f84d52890190eda29e00f8a2d3d9d52acf86f (stored 0%)
#   adding: .git/objects/ca/ (stored 0%)
#   adding: .git/objects/ca/bccda11f32f1968ba50f491a22225687e746fa (stored 0%)
#   adding: .git/objects/c7/ (stored 0%)
#   adding: .git/objects/c7/c858d65c791515ec532b2973c92c03152ecad9 (stored 0%)
#   adding: .git/objects/c7/a74839b4b2db5009c8705e85f0904c061a4875 (stored 0%)
#   adding: .git/objects/49/ (stored 0%)
#   adding: .git/objects/49/d1ae38f344b35535415957feb5cb9df0358953 (stored 0%)
#   adding: .git/objects/26/ (stored 0%)
#   adding: .git/objects/26/ce5f09a2168be1f1243fee2a1878b76688f851 (stored 0%)
#   adding: .git/objects/71/ (stored 0%)
#   adding: .git/objects/71/9a9d24b78897360215f2ff94b55e9db9d06564 (stored 0%)
#   adding: .git/objects/16/ (stored 0%)
#   adding: .git/objects/16/6da0e8e833e21ef8bf276bcf9a0c2e7811961c (stored 0%)
#   adding: .git/objects/9b/ (stored 0%)
#   adding: .git/objects/9b/b828376d7e1de6cc96f331314f65797f3b7eb4 (stored 0%)
#   adding: .git/info/ (stored 0%)
#   adding: .git/info/exclude (deflated 28%)
#   adding: .git/config (deflated 30%)
#   adding: .git/description (deflated 14%)
#   adding: .git/index (deflated 37%)
#   adding: .git/refs/ (stored 0%)
#   adding: .git/refs/remotes/ (stored 0%)
#   adding: .git/refs/remotes/origin/ (stored 0%)
#   adding: .git/refs/remotes/origin/HEAD (stored 0%)
#   adding: .git/refs/heads/ (stored 0%)
#   adding: .git/refs/heads/master (deflated 2%)
#   adding: .git/refs/tags/ (stored 0%)
